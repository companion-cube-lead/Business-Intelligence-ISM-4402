# %% [markdown]
# For this week's assigment, we will explore pandas and Python's random functions for us to sample a dataframe

# %%
import pandas as pd
import numpy as np
Location = "gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %% [markdown]
# This is the code to randomly sample a dataframe. Although it's simple to change the amount of rows to resample, it's important to understand what the function is doing underneath. We are leveraging the Python random functions to shuffle in the indices of our dataframe and return a dataframe (take) basked on the shuffle indices.

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#          fname       lname  gender  age  exercise  hours  grade  \
# 1188      Lane  Villarreal    male   18         1      8   76.0
# 1627      Dora      Dalton  female   14         5     10   89.9
# 886    Charles        Gray    male   14         3      7   79.1
# 66       Regan       Foley  female   16         2      9   77.4
# 1735     Xenos     Workman    male   14         1     10   85.5
# ...        ...         ...     ...  ...       ...    ...    ...
# 838       Dora      Hewitt  female   19         2      3   65.4
# 638   Virginia      Murphy  female   17         4     12   81.6
# 1410   Maxwell      Rhodes    male   18         3     11   77.9
# 694      Wylie   Alexander    male   16         3     13   82.0
# 428       Berk      Austin    male   19         5     11   88.1
#
#                                          address
# 1188  8528 N. Broad Avenue, San Angelo, TX 76901
# 1627          5 Central Court, Menasha, WI 54952
# ...

# %% [markdown]
# We can check whether the function is wokring by having the function loop a few times, we see that the observations shift for each print statement

# %%
for iterations in range(6): 
    print(df.take(np.random.permutation(len(df))[:500]))
# Out:
#         fname    lname  gender  age  exercise  hours  grade  \
# 1294  Kaitlin     Chen  female   18         3     12   79.5
# 1745  Leandra    Ortiz  female   15         1     15   89.5
# 888    Carter    Cross    male   14         4     12   92.4
# 1166     Dane   Carter    male   16         2     18   94.9
# 1506  Timothy  Oconnor    male   15         0     15   96.7
# ...       ...      ...     ...  ...       ...    ...    ...
# 1055    Plato  Holcomb    male   16         1      7   76.1
# 1267   Tucker  Coleman    male   16         4     17   95.6
# 457      Myra  Parrish  female   19         5     15  100.0
# 1434  Blossom    Henry  female   18         3      5   72.7
# 1134  Malcolm    Beach    male   18         4     14   99.2
#
#                                               address
# 1294  535 Alderwood Street, Capitol Heights, MD 20743
# 1745             7454 Halifax St., Holbrook, NY 11741
# 888                   87 Williams St., Kent, OH 44240
# ...
